# %% [markdown]
# ## Homework
#
# The goal of this homework is to familiarize users with workflow orchestration.
#
# Start with the orchestrate.py file in the 03-orchestration/3.4 folder
# of the course repo: https://github.com/DataTalksClub/mlops-zoomcamp/blob/main/03-orchestration/3.4/orchestrate.py
#
#
# ## Q1. Human-readable name
#
# You’d like to give the first task, `read_data` a nicely formatted name.
# How can you specify a task name?
#
# > Hint: look in the docs at https://docs.prefect.io or
# > check out the doc string in a code editor.
#
# - `@task(retries=3, retry_delay_seconds=2, name="Read taxi data")`
# - `@task(retries=3, retry_delay_seconds=2, task_name="Read taxi data")`
# - `@task(retries=3, retry_delay_seconds=2, task-name="Read taxi data")`
# - `@task(retries=3, retry_delay_seconds=2, task_name_function=lambda x: f"Read taxi data")`

# %%
! prefect --version
# Out:
# 2.10.8

# %% [markdown]
# https://docs.prefect.io/2.10.13/tutorial/flow-task-config/
#
# ``` python
# from prefect import flow, task
#
# @task(
#     name="My Example Task",
#     description="An example task for a tutorial."
# )
# def my_task():
#     # do some work
# ```

# %% [markdown]
# ## Q2. Cron
#
# Cron is a common scheduling specification for workflows.
#
# Using the flow in `orchestrate.py`, create a deployment.
# Schedule your deployment to run on the third day of every month at 9am UTC.
# What’s the cron schedule for that?
#
# - `0 9 3 * *`
# - `0 0 9 3 *`
# - `9 * 3 0 *`
# - `* * 9 3 0`
#
# ![image.png](attachment:2a5ecd8b-c13e-45ee-87c2-e6b87dc89986.png)

# %% [markdown]
# ## Q3. RMSE
#
# Download the January 2023 Green Taxi data and use it for your training data.
# Download the February 2023 Green Taxi data and use it for your validation data.
#
# Make sure you upload the data to GitHub so it is available for your deployment.
#
# Create a custom flow run of your deployment from the UI. Choose Custom
# Run for the flow and enter the file path as a string on the JSON tab under Parameters.
#
# Make sure you have a worker running and polling the correct work pool.
#
# View the results in the UI.
#
# What’s the final RMSE to five decimal places?
#
# - 6.67433
# - 5.19931
# - 8.89443
# - 9.12250

# %%
! python ./orchestrate.py data/raw/green_tripdata_2023-01.parquet data/raw/green_tripdata_2023-02.parquet
# Out:
# data/raw/green_tripdata_2023-01.parquet
# data/raw/green_tripdata_2023-02.parquet
# 16:57:23.711 | INFO    | prefect.engine - Created flow run 'unnatural-aardwark' for flow 'main-flow'
# 16:57:24.066 | INFO    | Flow run 'unnatural-aardwark' - Created task run 'Read taxi data-0' for task 'Read taxi data'
# 16:57:24.068 | INFO    | Flow run 'unnatural-aardwark' - Executing 'Read taxi data-0' immediately...
# 16:57:24.675 | INFO    | Task run 'Read taxi data-0' - Finished in state Completed()
# 16:57:24.712 | INFO    | Flow run 'unnatural-aardwark' - Created task run 'Read taxi data-1' for task 'Read taxi data'
# 16:57:24.713 | INFO    | Flow run 'unnatural-aardwark' - Executing 'Read taxi data-1' immediately...
# 16:57:25.034 | INFO    | Task run 'Read taxi data-1' - Finished in state Completed()
# 16:57:25.073 | INFO    | Flow run 'unnatural-aardwark' - Created task run 'add_features-0' for task 'add_features'
# 16:57:25.074 | INFO    | Flow run 'unnatural-aardwark' - Executing 'add_features-0' immediately...
# 16:57:25.701 | INFO    | Task run 'add_features-0' - Finished in state Completed()
# 16:57:25.738 | INFO    | Flow run 'unnatural-aardwark' - Created task run 'train_best_model-0' for task 'train_best_model'
# 16:57:25.739 | INFO    | Flow run 'unnatural-aardwark' - Executing 'train_best_model-0' immediately...
# [16:57:25] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# 16:57:26.031 | INFO    | Task run 'train_best_model-0' - [0]    validation-rmse:15.01627
# 16:57:26.164 | INFO    | Task run 'train_best_model-0' - [1]    validation-rmse:13.77591
# 16:57:26.277 | INFO    | Task run 'train_best_model-0' - [2]    validation-rmse:12.66953
# 16:57:26.389 | INFO    | Task run 'train_best_model-0' - [3]    validation-rmse:11.68972
# 16:57:26.503 | INFO    | Task run 'train_best_model-0' - [4]    validation-rmse:10.81927
# 16:57:26.615 | INFO    | Task run 'train_best_model-0' - [5]    validation-rmse:10.05352
# 16:57:26.724 | INFO    | Task run 'train_best_model-0' - [6]    validation-rmse:9.37638
# 16:57:26.830 | INFO    | Task run 'train_best_model-0' - [7]    validation-rmse:8.78514
# 16:57:26.933 | INFO    | Task run 'train_best_model-0' - [8]    validation-rmse:8.26684
# 16:57:27.037 | INFO    | Task run 'train_best_model-0' - [9]    validation-rmse:7.81889
# 16:57:27.139 | INFO    | Task run 'train_best_model-0' - [10]   validation-rmse:7.42994
# 16:57:27.242 | INFO    | Task run 'train_best_model-0' - [11]   validation-rmse:7.09348
# 16:57:27.349 | INFO    | Task run 'train_best_model-0' - [12]   validation-rmse:6.80836
# 16:57:27.455 | INFO    | Task run 'train_best_model-0' - [13]   validation-rmse:6.56211
# 16:57:27.560 | INFO    | Task run 'train_best_model-0' - [14]   validation-rmse:6.35332
# 16:57:27.661 | INFO    | Task run 'train_best_model-0' - [15]   validation-rmse:6.17838
# 16:57:27.761 | INFO    | Task run 'train_best_model-0' - [16]   validation-rmse:6.02763
# 16:57:27.852 | INFO    | Task run 'train_best_model-0' - [17]   validation-rmse:5.90232
# 16:57:27.939 | INFO    | Task run 'train_best_model-0' - [18]   validation-rmse:5.79691
# 16:57:28.029 | INFO    | Task run 'train_best_model-0' - [19]   validation-rmse:5.70817
# 16:57:28.139 | INFO    | Task run 'train_best_model-0' - [20]   validation-rmse:5.63182
# 16:57:28.236 | INFO    | Task run 'train_best_model-0' - [21]   validation-rmse:5.56852
# 16:57:28.351 | INFO    | Task run 'train_best_model-0' - [22]   validation-rmse:5.51520
# 16:57:28.444 | INFO    | Task run 'train_best_model-0' - [23]   validation-rmse:5.47115
# 16:57:28.533 | INFO    | Task run 'train_best_model-0' - [24]   validation-rmse:5.43421
# 16:57:28.612 | INFO    | Task run 'train_best_model-0' - [25]   validation-rmse:5.40206
# 16:57:28.695 | INFO    | Task run 'train_best_model-0' - [26]   validation-rmse:5.37653
# 16:57:28.780 | INFO    | Task run 'train_best_model-0' - [27]   validation-rmse:5.35308
# 16:57:28.859 | INFO    | Task run 'train_best_model-0' - [28]   validation-rmse:5.33437
# 16:57:28.935 | INFO    | Task run 'train_best_model-0' - [29]   validation-rmse:5.31842
# 16:57:29.012 | INFO    | Task run 'train_best_model-0' - [30]   validation-rmse:5.30434
# 16:57:29.089 | INFO    | Task run 'train_best_model-0' - [31]   validation-rmse:5.29293
# 16:57:29.169 | INFO    | Task run 'train_best_model-0' - [32]   validation-rmse:5.28270
# 16:57:29.249 | INFO    | Task run 'train_best_model-0' - [33]   validation-rmse:5.27307
# 16:57:29.314 | INFO    | Task run 'train_best_model-0' - [34]   validation-rmse:5.26638
# 16:57:29.381 | INFO    | Task run 'train_best_model-0' - [35]   validation-rmse:5.26043
# 16:57:29.447 | INFO    | Task run 'train_best_model-0' - [36]   validation-rmse:5.25512
# 16:57:29.513 | INFO    | Task run 'train_best_model-0' - [37]   validation-rmse:5.25088
# 16:57:29.577 | INFO    | Task run 'train_best_model-0' - [38]   validation-rmse:5.24664
# 16:57:29.649 | INFO    | Task run 'train_best_model-0' - [39]   validation-rmse:5.24209
# 16:57:29.713 | INFO    | Task run 'train_best_model-0' - [40]   validation-rmse:5.23909
# 16:57:29.775 | INFO    | Task run 'train_best_model-0' - [41]   validation-rmse:5.23607
# 16:57:29.838 | INFO    | Task run 'train_best_model-0' - [42]   validation-rmse:5.23344
# 16:57:29.901 | INFO    | Task run 'train_best_model-0' - [43]   validation-rmse:5.23200
# 16:57:29.962 | INFO    | Task run 'train_best_model-0' - [44]   validation-rmse:5.23097
# 16:57:30.025 | INFO    | Task run 'train_best_model-0' - [45]   validation-rmse:5.22865
# 16:57:30.088 | INFO    | Task run 'train_best_model-0' - [46]   validation-rmse:5.22775
# 16:57:30.149 | INFO    | Task run 'train_best_model-0' - [47]   validation-rmse:5.22687
# 16:57:30.237 | INFO    | Task run 'train_best_model-0' - [48]   validation-rmse:5.22582
# 16:57:30.300 | INFO    | Task run 'train_best_model-0' - [49]   validation-rmse:5.22487
# 16:57:30.362 | INFO    | Task run 'train_best_model-0' - [50]   validation-rmse:5.22442
# 16:57:30.425 | INFO    | Task run 'train_best_model-0' - [51]   validation-rmse:5.22332
# 16:57:30.485 | INFO    | Task run 'train_best_model-0' - [52]   validation-rmse:5.22236
# 16:57:30.549 | INFO    | Task run 'train_best_model-0' - [53]   validation-rmse:5.22142
# 16:57:30.611 | INFO    | Task run 'train_best_model-0' - [54]   validation-rmse:5.22022
# 16:57:30.673 | INFO    | Task run 'train_best_model-0' - [55]   validation-rmse:5.21987
# 16:57:30.736 | INFO    | Task run 'train_best_model-0' - [56]   validation-rmse:5.21908
# 16:57:30.800 | INFO    | Task run 'train_best_model-0' - [57]   validation-rmse:5.21873
# 16:57:30.866 | INFO    | Task run 'train_best_model-0' - [58]   validation-rmse:5.21820
# 16:57:30.931 | INFO    | Task run 'train_best_model-0' - [59]   validation-rmse:5.21787
# 16:57:30.996 | INFO    | Task run 'train_best_model-0' - [60]   validation-rmse:5.21702
# 16:57:31.063 | INFO    | Task run 'train_best_model-0' - [61]   validation-rmse:5.21632
# 16:57:31.129 | INFO    | Task run 'train_best_model-0' - [62]   validation-rmse:5.21571
# 16:57:31.193 | INFO    | Task run 'train_best_model-0' - [63]   validation-rmse:5.21404
# 16:57:31.258 | INFO    | Task run 'train_best_model-0' - [64]   validation-rmse:5.21348
# 16:57:31.320 | INFO    | Task run 'train_best_model-0' - [65]   validation-rmse:5.21290
# 16:57:31.387 | INFO    | Task run 'train_best_model-0' - [66]   validation-rmse:5.21262
# 16:57:31.447 | INFO    | Task run 'train_best_model-0' - [67]   validation-rmse:5.21181
# 16:57:31.511 | INFO    | Task run 'train_best_model-0' - [68]   validation-rmse:5.21179
# 16:57:31.575 | INFO    | Task run 'train_best_model-0' - [69]   validation-rmse:5.21113
# 16:57:31.640 | INFO    | Task run 'train_best_model-0' - [70]   validation-rmse:5.21051
# 16:57:31.703 | INFO    | Task run 'train_best_model-0' - [71]   validation-rmse:5.21000
# 16:57:31.769 | INFO    | Task run 'train_best_model-0' - [72]   validation-rmse:5.20944
# 16:57:31.833 | INFO    | Task run 'train_best_model-0' - [73]   validation-rmse:5.20928
# 16:57:31.897 | INFO    | Task run 'train_best_model-0' - [74]   validation-rmse:5.20890
# 16:57:31.960 | INFO    | Task run 'train_best_model-0' - [75]   validation-rmse:5.20840
# 16:57:32.025 | INFO    | Task run 'train_best_model-0' - [76]   validation-rmse:5.20723
# 16:57:32.086 | INFO    | Task run 'train_best_model-0' - [77]   validation-rmse:5.20677
# 16:57:32.152 | INFO    | Task run 'train_best_model-0' - [78]   validation-rmse:5.20653
# 16:57:32.217 | INFO    | Task run 'train_best_model-0' - [79]   validation-rmse:5.20608
# 16:57:32.307 | INFO    | Task run 'train_best_model-0' - [80]   validation-rmse:5.20599
# 16:57:32.378 | INFO    | Task run 'train_best_model-0' - [81]   validation-rmse:5.20558
# 16:57:32.444 | INFO    | Task run 'train_best_model-0' - [82]   validation-rmse:5.20516
# 16:57:32.511 | INFO    | Task run 'train_best_model-0' - [83]   validation-rmse:5.20428
# 16:57:32.573 | INFO    | Task run 'train_best_model-0' - [84]   validation-rmse:5.20377
# 16:57:32.636 | INFO    | Task run 'train_best_model-0' - [85]   validation-rmse:5.20323
# 16:57:32.703 | INFO    | Task run 'train_best_model-0' - [86]   validation-rmse:5.20281
# 16:57:32.768 | INFO    | Task run 'train_best_model-0' - [87]   validation-rmse:5.20294
# 16:57:32.839 | INFO    | Task run 'train_best_model-0' - [88]   validation-rmse:5.20271
# 16:57:32.907 | INFO    | Task run 'train_best_model-0' - [89]   validation-rmse:5.20245
# 16:57:32.976 | INFO    | Task run 'train_best_model-0' - [90]   validation-rmse:5.20201
# 16:57:33.040 | INFO    | Task run 'train_best_model-0' - [91]   validation-rmse:5.20186
# 16:57:33.101 | INFO    | Task run 'train_best_model-0' - [92]   validation-rmse:5.20146
# 16:57:33.163 | INFO    | Task run 'train_best_model-0' - [93]   validation-rmse:5.20144
# 16:57:33.227 | INFO    | Task run 'train_best_model-0' - [94]   validation-rmse:5.20096
# 16:57:33.290 | INFO    | Task run 'train_best_model-0' - [95]   validation-rmse:5.20087
# 16:57:33.373 | INFO    | Task run 'train_best_model-0' - [96]   validation-rmse:5.20016
# 16:57:33.433 | INFO    | Task run 'train_best_model-0' - [97]   validation-rmse:5.19983
# 16:57:33.496 | INFO    | Task run 'train_best_model-0' - [98]   validation-rmse:5.19931
# 16:57:33.559 | INFO    | Task run 'train_best_model-0' - [99]   validation-rmse:5.19931
# /home/ahairshi/anaconda3/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 16:57:36.930 | INFO    | Task run 'train_best_model-0' - Finished in state Completed()
# 16:57:36.983 | INFO    | Flow run 'unnatural-aardwark' - Finished in state Completed('All states completed.')

# %% [markdown]
# ## Q4. RMSE (Markdown Artifact)
#
# Download the February 2023 Green Taxi data and use it for your training data.
# Download the March 2023 Green Taxi data and use it for your validation data.
#
# Create a Prefect Markdown artifact that displays the RMSE for the validation data.
# Create a deployment and run it.
#
# What’s the RMSE in the artifact to two decimal places ?
#
# - 9.71
# - 12.02
# - 15.33
# - 5.37

# %%
! python ./orchestrate.py data/raw/green_tripdata_2023-02.parquet data/raw/green_tripdata_2023-03.parquet
# Out:
# data/raw/green_tripdata_2023-02.parquet
# data/raw/green_tripdata_2023-03.parquet
# 17:03:49.075 | INFO    | prefect.engine - Created flow run 'massive-elk' for flow 'main-flow'
# 17:03:49.428 | INFO    | Flow run 'massive-elk' - Created task run 'Read taxi data-0' for task 'Read taxi data'
# 17:03:49.430 | INFO    | Flow run 'massive-elk' - Executing 'Read taxi data-0' immediately...
# 17:03:49.970 | INFO    | Task run 'Read taxi data-0' - Finished in state Completed()
# 17:03:50.011 | INFO    | Flow run 'massive-elk' - Created task run 'Read taxi data-1' for task 'Read taxi data'
# 17:03:50.012 | INFO    | Flow run 'massive-elk' - Executing 'Read taxi data-1' immediately...
# 17:03:50.362 | INFO    | Task run 'Read taxi data-1' - Finished in state Completed()
# 17:03:50.407 | INFO    | Flow run 'massive-elk' - Created task run 'add_features-0' for task 'add_features'
# 17:03:50.409 | INFO    | Flow run 'massive-elk' - Executing 'add_features-0' immediately...
# 17:03:51.049 | INFO    | Task run 'add_features-0' - Finished in state Completed()
# 17:03:51.089 | INFO    | Flow run 'massive-elk' - Created task run 'train_best_model-0' for task 'train_best_model'
# 17:03:51.090 | INFO    | Flow run 'massive-elk' - Executing 'train_best_model-0' immediately...
# [17:03:51] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# 17:03:51.398 | INFO    | Task run 'train_best_model-0' - [0]    validation-rmse:15.33078
# 17:03:51.532 | INFO    | Task run 'train_best_model-0' - [1]    validation-rmse:14.09739
# 17:03:51.642 | INFO    | Task run 'train_best_model-0' - [2]    validation-rmse:12.99920
# 17:03:51.752 | INFO    | Task run 'train_best_model-0' - [3]    validation-rmse:12.02243
# 17:03:51.859 | INFO    | Task run 'train_best_model-0' - [4]    validation-rmse:11.15585
# 17:03:51.964 | INFO    | Task run 'train_best_model-0' - [5]    validation-rmse:10.39226
# 17:03:52.068 | INFO    | Task run 'train_best_model-0' - [6]    validation-rmse:9.71696
# 17:03:52.173 | INFO    | Task run 'train_best_model-0' - [7]    validation-rmse:9.12782
# 17:03:52.276 | INFO    | Task run 'train_best_model-0' - [8]    validation-rmse:8.60975
# 17:03:52.382 | INFO    | Task run 'train_best_model-0' - [9]    validation-rmse:8.15872
# 17:03:52.491 | INFO    | Task run 'train_best_model-0' - [10]   validation-rmse:7.76686
# 17:03:52.592 | INFO    | Task run 'train_best_model-0' - [11]   validation-rmse:7.42798
# 17:03:52.690 | INFO    | Task run 'train_best_model-0' - [12]   validation-rmse:7.13629
# 17:03:52.787 | INFO    | Task run 'train_best_model-0' - [13]   validation-rmse:6.88486
# 17:03:52.883 | INFO    | Task run 'train_best_model-0' - [14]   validation-rmse:6.67077
# 17:03:52.980 | INFO    | Task run 'train_best_model-0' - [15]   validation-rmse:6.48829
# 17:03:53.082 | INFO    | Task run 'train_best_model-0' - [16]   validation-rmse:6.33274
# 17:03:53.174 | INFO    | Task run 'train_best_model-0' - [17]   validation-rmse:6.19826
# 17:03:53.266 | INFO    | Task run 'train_best_model-0' - [18]   validation-rmse:6.08427
# 17:03:53.389 | INFO    | Task run 'train_best_model-0' - [19]   validation-rmse:5.98670
# 17:03:53.487 | INFO    | Task run 'train_best_model-0' - [20]   validation-rmse:5.90483
# 17:03:53.599 | INFO    | Task run 'train_best_model-0' - [21]   validation-rmse:5.83439
# 17:03:53.692 | INFO    | Task run 'train_best_model-0' - [22]   validation-rmse:5.77680
# 17:03:53.778 | INFO    | Task run 'train_best_model-0' - [23]   validation-rmse:5.72543
# 17:03:53.870 | INFO    | Task run 'train_best_model-0' - [24]   validation-rmse:5.68091
# 17:03:53.954 | INFO    | Task run 'train_best_model-0' - [25]   validation-rmse:5.64424
# 17:03:54.039 | INFO    | Task run 'train_best_model-0' - [26]   validation-rmse:5.61182
# 17:03:54.121 | INFO    | Task run 'train_best_model-0' - [27]   validation-rmse:5.58395
# 17:03:54.196 | INFO    | Task run 'train_best_model-0' - [28]   validation-rmse:5.56122
# 17:03:54.275 | INFO    | Task run 'train_best_model-0' - [29]   validation-rmse:5.54000
# 17:03:54.349 | INFO    | Task run 'train_best_model-0' - [30]   validation-rmse:5.52124
# 17:03:54.428 | INFO    | Task run 'train_best_model-0' - [31]   validation-rmse:5.50483
# 17:03:54.501 | INFO    | Task run 'train_best_model-0' - [32]   validation-rmse:5.49293
# 17:03:54.583 | INFO    | Task run 'train_best_model-0' - [33]   validation-rmse:5.48085
# 17:03:54.663 | INFO    | Task run 'train_best_model-0' - [34]   validation-rmse:5.47086
# 17:03:54.733 | INFO    | Task run 'train_best_model-0' - [35]   validation-rmse:5.46186
# 17:03:54.797 | INFO    | Task run 'train_best_model-0' - [36]   validation-rmse:5.45498
# 17:03:54.860 | INFO    | Task run 'train_best_model-0' - [37]   validation-rmse:5.44771
# 17:03:54.927 | INFO    | Task run 'train_best_model-0' - [38]   validation-rmse:5.44088
# 17:03:54.994 | INFO    | Task run 'train_best_model-0' - [39]   validation-rmse:5.43434
# 17:03:55.062 | INFO    | Task run 'train_best_model-0' - [40]   validation-rmse:5.43017
# 17:03:55.126 | INFO    | Task run 'train_best_model-0' - [41]   validation-rmse:5.42578
# 17:03:55.188 | INFO    | Task run 'train_best_model-0' - [42]   validation-rmse:5.42230
# 17:03:55.250 | INFO    | Task run 'train_best_model-0' - [43]   validation-rmse:5.41903
# 17:03:55.311 | INFO    | Task run 'train_best_model-0' - [44]   validation-rmse:5.41589
# 17:03:55.370 | INFO    | Task run 'train_best_model-0' - [45]   validation-rmse:5.41305
# 17:03:55.433 | INFO    | Task run 'train_best_model-0' - [46]   validation-rmse:5.41009
# 17:03:55.493 | INFO    | Task run 'train_best_model-0' - [47]   validation-rmse:5.40823
# 17:03:55.563 | INFO    | Task run 'train_best_model-0' - [48]   validation-rmse:5.40656
# 17:03:55.636 | INFO    | Task run 'train_best_model-0' - [49]   validation-rmse:5.40523
# 17:03:55.696 | INFO    | Task run 'train_best_model-0' - [50]   validation-rmse:5.40380
# 17:03:55.756 | INFO    | Task run 'train_best_model-0' - [51]   validation-rmse:5.40214
# 17:03:55.818 | INFO    | Task run 'train_best_model-0' - [52]   validation-rmse:5.40109
# 17:03:55.880 | INFO    | Task run 'train_best_model-0' - [53]   validation-rmse:5.40025
# 17:03:55.945 | INFO    | Task run 'train_best_model-0' - [54]   validation-rmse:5.39867
# 17:03:56.006 | INFO    | Task run 'train_best_model-0' - [55]   validation-rmse:5.39758
# 17:03:56.067 | INFO    | Task run 'train_best_model-0' - [56]   validation-rmse:5.39653
# 17:03:56.126 | INFO    | Task run 'train_best_model-0' - [57]   validation-rmse:5.39541
# 17:03:56.185 | INFO    | Task run 'train_best_model-0' - [58]   validation-rmse:5.39468
# 17:03:56.245 | INFO    | Task run 'train_best_model-0' - [59]   validation-rmse:5.39393
# 17:03:56.306 | INFO    | Task run 'train_best_model-0' - [60]   validation-rmse:5.39310
# 17:03:56.367 | INFO    | Task run 'train_best_model-0' - [61]   validation-rmse:5.39250
# 17:03:56.431 | INFO    | Task run 'train_best_model-0' - [62]   validation-rmse:5.39156
# 17:03:56.496 | INFO    | Task run 'train_best_model-0' - [63]   validation-rmse:5.39117
# 17:03:56.556 | INFO    | Task run 'train_best_model-0' - [64]   validation-rmse:5.39068
# 17:03:56.618 | INFO    | Task run 'train_best_model-0' - [65]   validation-rmse:5.38985
# 17:03:56.680 | INFO    | Task run 'train_best_model-0' - [66]   validation-rmse:5.38964
# 17:03:56.740 | INFO    | Task run 'train_best_model-0' - [67]   validation-rmse:5.38894
# 17:03:56.801 | INFO    | Task run 'train_best_model-0' - [68]   validation-rmse:5.38829
# 17:03:56.863 | INFO    | Task run 'train_best_model-0' - [69]   validation-rmse:5.38770
# 17:03:56.925 | INFO    | Task run 'train_best_model-0' - [70]   validation-rmse:5.38663
# 17:03:56.987 | INFO    | Task run 'train_best_model-0' - [71]   validation-rmse:5.38621
# 17:03:57.050 | INFO    | Task run 'train_best_model-0' - [72]   validation-rmse:5.38556
# 17:03:57.110 | INFO    | Task run 'train_best_model-0' - [73]   validation-rmse:5.38495
# 17:03:57.170 | INFO    | Task run 'train_best_model-0' - [74]   validation-rmse:5.38442
# 17:03:57.232 | INFO    | Task run 'train_best_model-0' - [75]   validation-rmse:5.38382
# 17:03:57.295 | INFO    | Task run 'train_best_model-0' - [76]   validation-rmse:5.38359
# 17:03:57.356 | INFO    | Task run 'train_best_model-0' - [77]   validation-rmse:5.38310
# 17:03:57.418 | INFO    | Task run 'train_best_model-0' - [78]   validation-rmse:5.38273
# 17:03:57.477 | INFO    | Task run 'train_best_model-0' - [79]   validation-rmse:5.38246
# 17:03:57.539 | INFO    | Task run 'train_best_model-0' - [80]   validation-rmse:5.38223
# 17:03:57.601 | INFO    | Task run 'train_best_model-0' - [81]   validation-rmse:5.38196
# 17:03:57.683 | INFO    | Task run 'train_best_model-0' - [82]   validation-rmse:5.38102
# 17:03:57.742 | INFO    | Task run 'train_best_model-0' - [83]   validation-rmse:5.38055
# 17:03:57.800 | INFO    | Task run 'train_best_model-0' - [84]   validation-rmse:5.38044
# 17:03:57.861 | INFO    | Task run 'train_best_model-0' - [85]   validation-rmse:5.38019
# 17:03:57.922 | INFO    | Task run 'train_best_model-0' - [86]   validation-rmse:5.37990
# 17:03:57.983 | INFO    | Task run 'train_best_model-0' - [87]   validation-rmse:5.37936
# 17:03:58.042 | INFO    | Task run 'train_best_model-0' - [88]   validation-rmse:5.37883
# 17:03:58.104 | INFO    | Task run 'train_best_model-0' - [89]   validation-rmse:5.37832
# 17:03:58.160 | INFO    | Task run 'train_best_model-0' - [90]   validation-rmse:5.37805
# 17:03:58.219 | INFO    | Task run 'train_best_model-0' - [91]   validation-rmse:5.37788
# 17:03:58.282 | INFO    | Task run 'train_best_model-0' - [92]   validation-rmse:5.37722
# 17:03:58.340 | INFO    | Task run 'train_best_model-0' - [93]   validation-rmse:5.37667
# 17:03:58.425 | INFO    | Task run 'train_best_model-0' - [94]   validation-rmse:5.37631
# 17:03:58.492 | INFO    | Task run 'train_best_model-0' - [95]   validation-rmse:5.37589
# 17:03:58.553 | INFO    | Task run 'train_best_model-0' - [96]   validation-rmse:5.37561
# 17:03:58.613 | INFO    | Task run 'train_best_model-0' - [97]   validation-rmse:5.37512
# 17:03:58.675 | INFO    | Task run 'train_best_model-0' - [98]   validation-rmse:5.37468
# 17:03:58.735 | INFO    | Task run 'train_best_model-0' - [99]   validation-rmse:5.37450
# /home/ahairshi/anaconda3/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 17:04:02.272 | INFO    | Task run 'train_best_model-0' - Finished in state Completed()
# 17:04:02.338 | INFO    | Flow run 'massive-elk' - Finished in state Completed('All states completed.')

# %% [markdown]
# ## Q5. Emails
#
#
# It’s often helpful to be notified when something with your dataflow doesn’t work
# as planned. Create an email notification for to use with your own Prefect server instance.
# In your virtual environment, install the prefect-email integration with
#
# ```bash
# pip install prefect-email
# ```
#
# Make sure you are connected to a running Prefect server instance through your
# Prefect profile.
# See the docs if needed: https://docs.prefect.io/latest/concepts/settings/#configuration-profiles
#
# Register the new block with your server with
#
# ```bash
# prefect block register -m prefect_email
# ```
#
# Remember that a block is a Prefect class with a nice UI form interface.
# Block objects live on the server and can be created and accessed in your Python code.
#
# See the docs for how to authenticate by saving your email credentials to
# a block and note that you will need an App Password to send emails with
# Gmail and other services. Follow the instructions in the docs.
#
# Create and save an `EmailServerCredentials` notification block.
# Use the credentials block to send an email.
#
# Test the notification functionality by running a deployment.
#
# What is the name of the pre-built prefect-email task function?
#
# - `send_email_message`
# - `email_send_message`
# - `send_email`
# - `send_message`

# %%
! pip install prefect-email
# Out:
# Collecting prefect-email
#   Downloading prefect_email-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: prefect>=2.0.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect-email) (2.10.8)
# Requirement already satisfied: fastapi>=0.93 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.95.2)
# Requirement already satisfied: httpx[http2]!=0.23.2,>=0.23 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.24.1)
# Requirement already satisfied: jsonpatch>=1.32 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (1.32)
# Requirement already satisfied: orjson>=3.7 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (3.8.1)
# Requirement already satisfied: docker>=4.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (6.1.2)
# Requirement already satisfied: cryptography>=36.0.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (39.0.1)
# Requirement already satisfied: apprise>=1.1.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (1.4.0)
# Requirement already satisfied: pendulum>=2.1.2 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (2.1.2)
# Requirement already satisfied: readchar>=4.0.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (4.0.5)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.22.0)
# Requirement already satisfied: pydantic>=1.10.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (1.10.8)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (4.4.0)
# Requirement already satisfied: toml>=0.10.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.10.2)
# Requirement already satisfied: packaging>=21.3 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (22.0)
# Requirement already satisfied: jinja2>=3.0.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (3.1.2)
# Requirement already satisfied: websockets>=10.4 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (11.0.3)
# Requirement already satisfied: dateparser>=1.1.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (1.1.8)
# Requirement already satisfied: aiosqlite>=0.17.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.19.0)
# Requirement already satisfied: click<8.2,>=8.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (8.0.4)
# Requirement already satisfied: alembic>=1.7.5 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (1.11.1)
# Requirement already satisfied: pyyaml>=5.4.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (6.0)
# Requirement already satisfied: jsonschema<5.0.0,>=3.2.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (4.17.3)
# Requirement already satisfied: pytz>=2021.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (2022.7)
# Requirement already satisfied: python-slugify>=5.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (5.0.2)
# Requirement already satisfied: sqlalchemy[asyncio]!=1.4.33,<2.0,>=1.4.22 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (1.4.39)
# Requirement already satisfied: griffe>=0.20.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.29.0)
# Requirement already satisfied: pathspec>=0.8.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.10.3)
# Requirement already satisfied: cloudpickle>=2.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (2.0.0)
# Requirement already satisfied: croniter>=1.0.12 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (1.3.15)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (2022.11.0)
# Requirement already satisfied: rich>=11.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (13.4.1)
# Requirement already satisfied: anyio>=3.4.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (3.5.0)
# Requirement already satisfied: coolname>=1.0.4 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (2.2.0)
# Requirement already satisfied: kubernetes>=24.2.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (26.1.0)
# Requirement already satisfied: asgi-lifespan>=1.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (2.1.0)
# Requirement already satisfied: asyncpg>=0.23 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.27.0)
# Requirement already satisfied: typer>=0.4.2 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from prefect>=2.0.0->prefect-email) (0.9.0)
# Requirement already satisfied: Mako in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from alembic>=1.7.5->prefect>=2.0.0->prefect-email) (1.2.4)
# Requirement already satisfied: idna>=2.8 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from anyio>=3.4.0->prefect>=2.0.0->prefect-email) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from anyio>=3.4.0->prefect>=2.0.0->prefect-email) (1.2.0)
# Requirement already satisfied: markdown in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from apprise>=1.1.0->prefect>=2.0.0->prefect-email) (3.4.1)
# Requirement already satisfied: certifi in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from apprise>=1.1.0->prefect>=2.0.0->prefect-email) (2022.12.7)
# Requirement already satisfied: requests in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from apprise>=1.1.0->prefect>=2.0.0->prefect-email) (2.28.1)
# Requirement already satisfied: requests-oauthlib in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from apprise>=1.1.0->prefect>=2.0.0->prefect-email) (1.3.1)
# Requirement already satisfied: python-dateutil in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from croniter>=1.0.12->prefect>=2.0.0->prefect-email) (2.8.2)
# Requirement already satisfied: cffi>=1.12 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from cryptography>=36.0.1->prefect>=2.0.0->prefect-email) (1.15.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from dateparser>=1.1.1->prefect>=2.0.0->prefect-email) (2022.7.9)
# Requirement already satisfied: tzlocal in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from dateparser>=1.1.1->prefect>=2.0.0->prefect-email) (5.0.1)
# Requirement already satisfied: urllib3>=1.26.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from docker>=4.0->prefect>=2.0.0->prefect-email) (1.26.14)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from docker>=4.0->prefect>=2.0.0->prefect-email) (0.58.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from fastapi>=0.93->prefect>=2.0.0->prefect-email) (0.27.0)
# Requirement already satisfied: colorama>=0.4 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from griffe>=0.20.0->prefect>=2.0.0->prefect-email) (0.4.6)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect>=2.0.0->prefect-email) (0.17.2)
# Requirement already satisfied: h2<5,>=3 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect>=2.0.0->prefect-email) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from jinja2>=3.0.0->prefect>=2.0.0->prefect-email) (2.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from jsonpatch>=1.32->prefect>=2.0.0->prefect-email) (2.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from jsonschema<5.0.0,>=3.2.0->prefect>=2.0.0->prefect-email) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from jsonschema<5.0.0,>=3.2.0->prefect>=2.0.0->prefect-email) (0.18.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from kubernetes>=24.2.0->prefect>=2.0.0->prefect-email) (2.19.1)
# Requirement already satisfied: setuptools>=21.0.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from kubernetes>=24.2.0->prefect>=2.0.0->prefect-email) (65.6.3)
# Requirement already satisfied: six>=1.9.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from kubernetes>=24.2.0->prefect>=2.0.0->prefect-email) (1.16.0)
# Requirement already satisfied: pytzdata>=2020.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from pendulum>=2.1.2->prefect>=2.0.0->prefect-email) (2020.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from python-slugify>=5.0->prefect>=2.0.0->prefect-email) (1.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from rich>=11.0->prefect>=2.0.0->prefect-email) (2.15.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from rich>=11.0->prefect>=2.0.0->prefect-email) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from sqlalchemy[asyncio]!=1.4.33,<2.0,>=1.4.22->prefect>=2.0.0->prefect-email) (2.0.1)
# Requirement already satisfied: h11>=0.8 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from uvicorn>=0.14.0->prefect>=2.0.0->prefect-email) (0.14.0)
# Requirement already satisfied: pycparser in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.1->prefect>=2.0.0->prefect-email) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=24.2.0->prefect>=2.0.0->prefect-email) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=24.2.0->prefect>=2.0.0->prefect-email) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=24.2.0->prefect>=2.0.0->prefect-email) (4.9)
# Requirement already satisfied: hyperframe<7,>=6.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect>=2.0.0->prefect-email) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect>=2.0.0->prefect-email) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.0->prefect>=2.0.0->prefect-email) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from requests->apprise>=1.1.0->prefect>=2.0.0->prefect-email) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from requests-oauthlib->apprise>=1.1.0->prefect>=2.0.0->prefect-email) (3.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ahairshi/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=24.2.0->prefect>=2.0.0->prefect-email) (0.4.8)
# Installing collected packages: prefect-email
# Successfully installed prefect-email-0.2.2

# %%
# !prefect block register -m prefect_email
# Out:
# Successfully registered 1 block
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Registered Blocks        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Email Server Credentials │
# └──────────────────────────┘
#
#  To configure the newly registered blocks, go to the Blocks page in the Prefect
# UI: http://127.0.0.1:4200/blocks/catalog

# %%
import prefect_email
dir(prefect_email)
# Out:
# ['EmailServerCredentials',
#  'SMTPServer',
#  'SMTPType',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'credentials',
#  'email_send_message',
#  'message']

# %% [markdown]
# ## Q6. Prefect Cloud
#
# The hosted Prefect Cloud lets you avoid running your own Prefect server and
# has automations that allow you to get notifications when certain events occur
# or don’t occur.
#
# Create a free forever Prefect Cloud account at [app.prefect.cloud](https://app.prefect.cloud/) and connect
# your workspace to it following the steps in the UI when you sign up.
#
# Set up an Automation from the UI that will send yourself an email when
# a flow run completes. Run one of your existing deployments and check
# your email to see the notification.
#
# Make sure your active profile is pointing toward Prefect Cloud and
# make sure you have a worker active.
#
# What is the name of the second step in the Automation creation process?
#
# - Details
# - Trigger
# - Actions
# - The end

# %% [markdown]
# ## Submit the results
#
# * Submit your results here: https://forms.gle/nVSYH5fGGamdY1LaA
# * You can submit your solution multiple times. In this case, only the last submission will be used
# * If your answer doesn't match options exactly, select the closest one
#
#
# ## Deadline
#
# The deadline for submitting is 12 June (Monday), 23:00 CEST (Berlin time).
#
# After that, the form will be closed.
